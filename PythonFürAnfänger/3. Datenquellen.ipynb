# %% [markdown]
# # Wie komme ich an die externen Daten?
#
# * Daten aus Textdateien
# * Strukturierte Daten aus Web
#     * JSON
#     * XML
# * Web-Scraping
# * Datenbanken

# %% [markdown]
# ### Textdateien vs. Binärdateien

# %% [markdown]
# Textdateien bestehen aus Textzeilen, durch Line-Separatoren getrennt
#
# Line-Separatoren
# * Unix: 0xD
# * Windows: 0xD 0xA

# %% [markdown]
# # Dateien lesen und schreiben

# %% [markdown]
# ## Textdateien lesen

# %% [markdown]
# Einfaches Beispiel

# %%
f = open('sample.txt')
for s in f:
    print(s)
f.close()

# %% [markdown]
# Suchen in einer Datei

# %%
f = open('sample.txt')
if 'world\n' in f:
    print("World is here")
f.close()

# %% [markdown]
# Die ganze Textdatei in RAM auslesen und Lines intern trennen

# %%
with open('sample.txt', 'r') as f:
    cnt = 0
    for line in f.readlines():
        line = str(line).rstrip()
        print ("Line: " + line)
        cnt += 1
        if 'world' in line:
            print ("Gefunden, line " + str(cnt))

# %% [markdown]
# Große Datei Line-nach-Line lesen

# %%
with open('sample.txt', 'r') as f:
    while True:
        line = f.readline()
        if line == '':
            break
        print (line, end='')

# %% [markdown]
# ## Binäre Dateien lesen

# %%
with open('sample.txt', 'rb') as f:
    for chr in f.read(10):
        print (chr)

# %% [markdown]
# ## Dateien schreieben

# %% [markdown]
# Textdatei nur schreiben

# %%
with open('sample_write.txt', 'w') as f:
    f.write('Hello!\n')
    f.write('This is my first file!\n')

# %% [markdown]
# Textdatei Lesen und Schreieben

# %%
with open('sample_read_write.txt', 'w+') as f:
    f.write('Hallo wieder!\n')
    f.write('This is my first file!\n')
    f.seek(0)
    print (f.read())

# %% [markdown]
# ## Falls kein 'with' statement: close() nicht vergessen!

# %%
f = open('sample_write.txt', 'w')
f.write('Hello!\n')
f.write('This is my first file!\n')
f.close()

# %% [markdown]
# # Achtung, Gefahr: utf-8 Dateien

# %% [markdown]
# ## Lesen von Dateien, die Unicode Chars enthalten im Textmodus kann zu Fehlern führen

# %%
f = open('sample_utf.txt')
for s in f:
    print(s)
f.close()

# %% [markdown]
# ## UTF-8 Dateien richtig lesen

# %%
import codecs
f = codecs.open("sample_utf.txt", "r", "utf-8")
for s in f:
    print(s)
f.close()

# %% [markdown]
# ## UTF-8 Dateien richtig schreiben

# %%
import codecs
f = codecs.open("sample_utf_w.txt", "w", "utf-8")
f.write('Привет! γεια!')
f.close()

# %% [markdown]
# # Strukturierte Daten aus Web lesen

# %% [markdown]
# Beispiel: einfache Daten lesen

# %%
import requests

r = requests.get('http://ip.jsontest.com/')

print('Encoding: ', r.encoding)

print ('Content: ', r.content)
# Out:
# Encoding:  ISO-8859-1
# Content:  b'{"ip": "83.136.72.12"}\n'

# %% [markdown]
# ## Beispiel: JSON zu Dict umwandeln

# %% [markdown]
# ## c:> conda install ujson

# %%
import ujson
dict = ujson.loads(r.content)
dict
# Out:
# {'ip': '83.136.72.12'}

# %% [markdown]
# ### UTF-8 Daten

# %%
import requests

r = requests.get('https://news.google.com/news/feeds?output=rss')

print('Encoding: ', r.encoding)

utf = r.content.decode('utf-8')

dict = ujson.loads(utf)

dict['synsets'][4]
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     742     addrlist = []
# --> 743     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     744         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001B9215290B8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648             retries = retries.increment(method, url, error=e, _pool=self,
# --> 649                                         _stacktrace=sys.exc_info()[2])
#     650             retries.sleep()
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /news/feeds?output=rss (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001B9215290B8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-53-b54252c17023> in <module>()
#       1 import requests
#       2
# ----> 3 r = requests.get('https://news.google.com/news/feeds?output=rss')
#       4
#       5 print('Encoding: ', r.encoding)
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     500                 raise ProxyError(e, request=request)
#     501
# --> 502             raise ConnectionError(e, request=request)
#     503
#     504         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='news.google.com', port=443): Max retries exceeded with url: /news/feeds?output=rss (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x000001B9215290B8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))

# %% [markdown]
# # XML aus Web Lesen

# %%
import requests

r = requests.get('http://rus.delfi.lv/sport_rss.php')

print('Encoding: ', r.encoding)

r.content 
#utf = r.content.decode('utf-8')

#dict = ujson.loads(utf)

#dict
# Out:
# Encoding:  None
# b'<?xml version="1.0" encoding="UTF-8"?>\n<rss version="2.0">\n\t<channel>\n\t\t<title>\xd0\xa1\xd0\xbf\xd0\xbe\xd1\x80\xd1\x82</title>\n\t\t<link>http://rus.delfi.lv</link>\n\t\t<description>DELFI: \xd1\x81\xd0\xb2\xd0\xb5\xd0\xb6\xd0\xb8\xd0\xb5 \xd0\xbd\xd0\xbe\xd0\xb2\xd0\xbe\xd1\x81\xd1\x82\xd0\xb8 \xd1\x81\xd0\xbf\xd0\xbe\xd1\x80\xd1\x82\xd0\xb0</description>\n\t\t<language>ru</language>\n\t\t<copyright>A/S DELFI, 2009. All rights reserved.</copyright>\n\t\t<lastBuildDate>Wed, 21 Jun 2017 18:24:36 +0300</lastBuildDate>\n\t\t<generator>PHP</generator>\n\t\t\n\t\t\t<url>http://g1.delphi.lv/u/delfi.gif</url>\n\t\t\t<link>http://rus.delfi.lv</link>\n\t\t\t<title>\xd0\xa1\xd0\xbf\xd0\xbe\xd1\x80\xd1\x82</title>\n\t\t\n\t\t\t\t\n\t\t\t<item>\n\t\t\t\t<title>\xd0\x9e\xd1\x81\xd0\xba\xd0\xb0\xd0\xbd\xd0\xb4\xd0\xb0\xd0\xbb\xd0\xb8\xd0\xb2\xd1\x88\xd0\xb8\xd0\xb9\xd1\x81\xd1\x8f \xd0\xb3\xd0\xbb\xd0\xb0\xd0\xb2\xd0\xb0 &quot;\xd0\x9b\xd0\xb5\xd1\x82\xd1\x83\xd0\xb2\xd0\xbe\xd1\x81 \xd0\xa0\xd0\xb8\xd1\x82\xd0\xb0\xd1\x81&quot; \xd0\xbf\xd0\xbe\xd0\xba\xd0\xb8\xd0\xbd\xd1\x83\xd0\xbb \xd0\xba\xd0\xbb\xd1\x83\xd0\xb1, \xd0\xbd\xd0\xbe\xd0\xb2\xd1\x8b\xd0\xb9 \xd0\xb2\xd0\xbb\xd0\xb0\xd0\xb4\xd0\xb5\xd0\xbb\xd0\xb5\xd1\x86&amp;nbsp;\xe2\x80\x94 \xd0\xb8\xd0\xb3\xd1\x80\xd0\xbe\xd0\xba \xd0\xb2 \xd0\xbf\xd0\xbe\xd0\xba\xd0\xb5\xd1\x80</title>\n\t\t\t\t<link>http://rus.delfi.lv/news/sport/worldsport/oskandalivshijsya-glava-letuvos-ritas-pokinul-klub-novyj-vladelec-igrok-v-poker.d?id=48976545</link>\n\t\t\t\t<guid>http://rus.delfi.lv/news/sport/worldsport/oskandalivshijsya-glava-letuvos-ritas-pokinul-klub-novyj-vladelec-igrok-v-poker.d?id=48976545</guid>\n\t\t\t\t<category>\xd0\xa1\xd0\xbf\xd0\xbe\xd1\x80\xd1\x82 \xd0\xb2 \xd0\xbc\xd0\xb8\xd1\x80\xd0\xb5</category>\n\t\t\t\t<description>\n&lt;img src="http://g1.delphi.lv/images/pix/207x130/SDjeqwoX8-k/gedvydas-vainauskas-48960519.jpg" border="0" align="left"/&gt;\xd0\x9f\xd1\x80\xd0\xb5\xd0\xb7\xd0\xb8\xd0\xb4\xd0\xb5\xd0\xbd\xd1\x82 \xd0\xbb\xd0\xb8\xd1\x82\xd0\xbe\xd0\xb2\xd1\x81\xd0\xba\xd0\xbe\xd0\xb3\xd0\xbe \xd0\