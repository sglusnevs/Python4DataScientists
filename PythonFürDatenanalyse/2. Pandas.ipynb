# %% [markdown]
# # Pandas -- "Excel für Python, aber besser"
#
# * Series
# * DataFrame
# * Daten-Auswahl
# * Benutzerdefinierte Auswahl
# * Data Input und Output
# * Abwesende Daten
# * GroupBy
# * Merging, Joining, Concatenation
# * Operations

# %% [markdown]
# Installation (in Anaconda schon inbegriffen)
#
#     conda install pandas
# oder
#
#     pip install pandas

# %% [markdown]
# # Series

# %% [markdown]
# Series ist ein Datentyp von Pandas, um Reiehenfolgen-Artige Data (wie Time-Series) zu behandeln.
#
# Series kann man aus Python List, Numpy Array, Python Dictionary erstellen.

# %%
import pandas as pd

pd.Series([10, 20, 30, 40, 50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import numpy as np

pd.Series(np.array([10, 20, 30, 40, 50]))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int32

# %%
md = {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50}

pd.Series(md)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
labels = ['n', 'k', 'j', 'x', 'y']

pd.Series([10, 20, 30, 40, 50], index=labels)
# Out:
# n    10
# k    20
# j    30
# x    40
# y    50
# dtype: int64

# %% [markdown]
# Indices ermöglichen schnellen Zugriff zu Daten

# %%
data = [43, 12, 54, 12, 56]
labels = ['KY', 'NY', 'OR', 'WY', 'AL']
s1 = pd.Series(data, labels)
s1
# Out:
# KY    43
# NY    12
# OR    54
# WY    12
# AL    56
# dtype: int64

# %%
data = [65, 34, 56, 23, 56]
labels = ['KY', 'WY', 'FL', 'TN', 'AL']
s2 = pd.Series(data, labels)
s2
# Out:
# KY    65
# WY    34
# FL    56
# TN    23
# AL    56
# dtype: int64

# %%
s3 = s1 + s2; s3
# Out:
# AL    112.0
# FL      NaN
# KY    108.0
# NY      NaN
# OR      NaN
# TN      NaN
# WY     46.0
# dtype: float64

# %% [markdown]
# ### Series können beliebige Daten enthalten

# %% [markdown]
# ### Abwesende Werte in Series

# %%
s3.dropna(inplace=False)
# Out:
# AL    112.0
# KY    108.0
# WY     46.0
# dtype: float64

# %%
s3
# Out:
# AL    112.0
# FL      NaN
# KY    108.0
# NY      NaN
# OR      NaN
# TN      NaN
# WY     46.0
# dtype: float64

# %%
s3.fillna(0.0)
# Out:
# AL    112.0
# FL      0.0
# KY    108.0
# NY      0.0
# OR      0.0
# TN      0.0
# WY     46.0
# dtype: float64

# %%
s3.fillna(s3.mean())

# %%
s3.head(2)
# Out:
# AL    112.0
# FL      NaN
# dtype: float64

# %%
s3.tail()
# Out:
# KY    108.0
# NY      NaN
# OR      NaN
# TN      NaN
# WY     46.0
# dtype: float64

# %% [markdown]
# # DataFrame

# %%
from numpy.random import randn
import pandas as pd

df = pd.DataFrame(randn(5, 4), columns='A B C D'.split(), index='WY KY WS AL FL'.split()); df
# Out:
#            A         B         C         D
# WY -0.295598 -0.446567 -0.196448  1.303685
# KY -0.365105 -0.725048  0.650752  0.317721
# WS -0.910884 -0.703976  0.320993 -0.152861
# AL -0.310119  1.801487 -0.145795  1.226468
# FL  0.519044  0.230875  1.152704  0.395930

# %% [markdown]
# ### Daten-Auswahl

# %%
df['A']
# Out:
# WY   -0.295598
# KY   -0.365105
# WS   -0.910884
# AL   -0.310119
# FL    0.519044
# Name: A, dtype: float64

# %%
df['A']['WY']
# Out:
# -0.29559757984054774

# %%
df[['A', 'B']]
# Out:
#            A         B
# WY -0.295598 -0.446567
# KY -0.365105 -0.725048
# WS -0.910884 -0.703976
# AL -0.310119  1.801487
# FL  0.519044  0.230875

# %%
df.loc['WY']
# Out:
# A   -0.295598
# B   -0.446567
# C   -0.196448
# D    1.303685
# Name: WY, dtype: float64

# %%
df.loc['WY']['A']
# Out:
# -0.29559757984054774

# %% [markdown]
# Achtung, eine Falle: wenn man statt 'loc[]' versucht 'loc()' anzuwenden, werden nicht die Daten, sondern 'loc()' Object zurückgegeben

# %%
df.loc['WY', 'A']
# Out:
# -0.29559757984054774

# %% [markdown]
# Achtung, eine Falle: ein Subset von den Daten kann man mit df.loc[] bekommen, aber nicht mit dem Auswahl aus dem DataFrame Objekt selbst, wie df[['WY', 'KY'], ['A', 'B']]

# %%
type(df.loc[['WY', 'KY'], ['A', 'B']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# .iloc() -- Datenreihe nach Position suchen

# %%
df
# Out:
#            A         B         C         D
# WY -0.295598 -0.446567 -0.196448  1.303685
# KY -0.365105 -0.725048  0.650752  0.317721
# WS -0.910884 -0.703976  0.320993 -0.152861
# AL -0.310119  1.801487 -0.145795  1.226468
# FL  0.519044  0.230875  1.152704  0.395930

# %%
df.iloc[0]
# Out:
# A   -0.295598
# B   -0.446567
# C   -0.196448
# D    1.303685
# Name: WY, dtype: float64

# %%
df.iloc[0][['A', 'B']]
# Out:
# A   -0.295598
# B   -0.446567
# Name: WY, dtype: float64

# %% [markdown]
# # Benutzerdefinierte Auswahl

# %%
df
# Out:
#            A         B         C         D
# WY -0.295598 -0.446567 -0.196448  1.303685
# KY -0.365105 -0.725048  0.650752  0.317721
# WS -0.910884 -0.703976  0.320993 -0.152861
# AL -0.310119  1.801487 -0.145795  1.226468
# FL  0.519044  0.230875  1.152704  0.395930

# %%
df > 0
# Out:
#         A      B      C      D
# WY  False  False  False   True
# KY  False  False   True   True
# WS  False  False   True  False
# AL  False   True  False   True
# FL   True   True   True   True

# %%
(df['D']>0).value_counts()
# Out:
# True     4
# False    1
# Name: D, dtype: int64

# %%
df[df > 0]
# Out:
#            A         B         C         D
# WY       NaN       NaN       NaN  1.303685
# KY       NaN       NaN  0.650752  0.317721
# WS       NaN       NaN  0.320993       NaN
# AL       NaN  1.801487       NaN  1.226468
# FL  0.519044  0.230875  1.152704  0.395930

# %%
df[df['D'] > 0]
# Out:
#            A         B         C         D
# WY -0.295598 -0.446567 -0.196448  1.303685
# KY -0.365105 -0.725048  0.650752  0.317721
# AL -0.310119  1.801487 -0.145795  1.226468
# FL  0.519044  0.230875  1.152704  0.395930

# %%
df[(df['D'] > 0) & (df['B'] < 0)]
# Out:
#            A         B         C         D
# WY -0.295598 -0.446567 -0.196448  1.303685
# KY -0.365105 -0.725048  0.650752  0.317721

# %% [markdown]
# Achtung: nur binäre Operatoren verwenden (|, &, ~), keine or/and! ()s sind notwendig

# %% [markdown]
# # Group by

# %%
import pandas as pd

data = {'Company':['GOOG','FB','MSFT','MSFT','GOOG','FB'],
       'Person':['Bob','Charlie','Sam','Vanessa','Charlie','Alice'],
       'Sales':[300,100,300,224,113,351]}

df = pd.DataFrame(data)

df
# Out:
#   Company   Person  Sales
# 0    GOOG      Bob    300
# 1      FB  Charlie    100
# 2    MSFT      Sam    300
# 3    MSFT  Vanessa    224
# 4    GOOG  Charlie    113
# 5      FB    Alice    351

# %%
df.groupby('Company').mean()
# Out:
#          Sales
# Company
# FB       225.5
# GOOG     206.5
# MSFT     262.0

# %%
df.groupby('Company').mean()

# %%
df.groupby('Company').std()
# Out:
#               Sales
# Company
# FB       177.483802
# GOOG     132.228968
# MSFT      53.740115

# %%
df.groupby('Company').count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
df.groupby('Company').describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  225.5  177.483802  100.0  162.75  225.5  288.25  351.0
# GOOG      2.0  206.5  132.228968  113.0  159.75  206.5  253.25  300.0
# MSFT      2.0  262.0   53.740115  224.0  243.00  262.0  281.00  300.0

# %% [markdown]
# # Operations

# %%
import pandas as pd
df = pd.DataFrame({'A':[1,2,3,4],'B':[444,555,666,444],'C':['abc','def','ghi','xyz']})
df.head()
# Out:
#    A    B    C
# 0  1  444  abc
# 1  2  555  def
# 2  3  666  ghi
# 3  4  444  xyz

# %%
df['B'].nunique()
# Out:
# 3

# %%
df['B'].count() - df['B'].nunique()
# Out:
# 1

# %%
df['B'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: B, dtype: int64

# %%
df['Q'] = df['B'].apply(lambda n: n**3)

# %%
df
# Out:
#    A    B    C          Q
# 0  1  444  abc   87528384
# 1  2  555  def  170953875
# 2  3  666  ghi  295408296
# 3  4  444  xyz   87528384

# %%
del df['Q']
df
# Out:
#    A    B    C
# 0  1  444  abc
# 1  2  555  def
# 2  3  666  ghi
# 3  4  444  xyz

# %%
df.sort_values(by=['B', 'C'], ascending=[False, True])
# Out:
#    A    B    C
# 2  3  666  ghi
# 1  2  555  def
# 0  1  444  abc
# 3  4  444  xyz

# %% [markdown]
# # Data Input und Output

# %% [markdown]
# ### Aus Web: pandas entziffert HTML-Tabellen selbständig

# %%
tables = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html'); 

df = tables[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 7 columns):
# Bank Name                553 non-null object
# City                     553 non-null object
# ST                       553 non-null object
# CERT                     553 non-null int64
# Acquiring Institution    553 non-null object
# Closing Date             553 non-null object
# Updated Date             553 non-null object
# dtypes: int64(1), object(6)
# memory usage: 30.3+ KB

# %%
df.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution      Closing Date  Updated Date
# 0   1802            United Fidelity Bank, fsb      May 26, 2017  June 1, 2017
# 1  30003  First-Citizens Bank & Trust Company       May 5, 2017  June 1, 2017
# 2  58302                         Whitney Bank    April 28, 2017  May 23, 2017
# 3  35495                    Cache Valley Bank     March 3, 2017  May 18, 2017
# 4  19328                  State Bank of Texas  January 27, 2017  May 18, 2017

# %%
df.groupby('CERT').describe()
# Out:
#       Acquiring Institution         \
#                       count unique
# CERT
# 91                        1      1
# 151                       1      1
# 182                       1      1
# 416                       1      1
# 513                       1      1
# 916                       1      1
# 1006                      1      1
# 1056                      1      1
# 1249                      1      1
# 1252                      1      1
# 1361                      1      1
# 1690                      1      1
# 1802                      1      1
# 1909                      1      1
# 1971                      1      1
# 2119                      1      1
# 2303                      1      1
# 2994                      1      1
# 3287                      1      1
# 3644                      1      1
# 3731                      1      1
# 3735                      1      1
# 3815                      1      1
# 4077                      1      1
# 4392                      1      1
# 4614                      1      1
# 4731                      1      1
# 58420        June 3, 2011    1     1      1  SC    1            1      1
# 58429      April 23, 2010    1     1      1  IL    1            1      1
# 58495   December 17, 2010    1     1      1  GA    1            1      1
# 58531   February 28, 2014    1     1      1  PA    1            1      1
# 58539      April 29, 2011    1     1      1  GA    1            1      1
# 58701        May 10, 2013    1     1      1  NC    1            1      1
#
#
#                       top freq
# CERT
# 91      November 17, 2016    1
# 151        March 21, 2014    1
# 182           May 4, 2016    1
# 416      February 5, 2015    1
# 513      January 22, 2013    1
# 916       January 6, 2016    1
# 1006       March 21, 2014    1
# 1056      August 19, 2014    1
# 1249        April 9, 2008    1
# 1252      August 23, 2012    1
# 1361        July 30, 2013    1
# 1690       August 8, 2016    1
# 1802         June 1, 2017    1
# 1909      August 21, 2012    1
# 1971      August 28, 2012    1
# 2119     October 17, 2015    1
# 2303   September 12, 2012    1
# 2994   September 12, 2012    1
# 3287      August 19, 2014    1
# 3644      August 20, 2012    1
# 3731    November 22, 2013    1
# 3735      August 23, 2012    1
# 3815       March 17, 2005    1
# 4077       April 13, 2017    1
# 4392      August 16, 2012    1
# 4614   September 21, 2015    1
# 4731        July 19, 2016    1
# 4744      August 23, 2012    1
# 4754   September 12, 2016    1
# 4862       March 26, 2015    1
# ...                   ...  ...
# 58072  September 14, 2012    1
# 58073      March 21, 2014    1
# 58087  September 12, 2016    1
# 58104      April 13, 2016    1
# 58125       July 11, 2016    1
# 58182    February 9, 2017    1
# 58185       June 26, 2014    1
# 58197        June 6, 2016    1
# 58205    February 9, 2017    1
# 58222      March 21, 2014    1
# 58226      March 21, 2014    1
# 58238      March 21, 2014    1
# 58241     August 16, 2012    1
# 58273      March 21, 2014    1
# 58283     October 9, 2012    1
# 58302        May 23, 2017    1
# 58308       July 11, 2016    1
# 58315      March 21, 2014    1
# 58336     August 22, 2012    1
# 58343      March 21, 2014    1
# 58352    January 15, 2013    1
# 58358       July 12, 2013    1
# 58362        June 6, 2016    1
# 58399    October 20, 2016    1
# 58420      March 21, 2014    1
# 58429     August 23, 2012    1
# 58495      March 21, 2014    1
# 58531       March 3, 2015    1
# 58539  September 21, 2015    1
# 58701      August 8, 2016    1
#
# [553 rows x 24 columns]

# %% [markdown]
# # Aus Excel

# %%
df = pd.read_excel('Mappe1.xlsx',sheetname='Tabelle1')

# %%
df[4].sum()
# Out:
# 44

# %% [markdown]
# # Nach Excel

# %%
# df.to_excel('Mappe1Neu.xlsx', sheet_name='Tabelle3')
import xlsxwriter

xlsxwriter.

# %% [markdown]
# # Aus CSV

# %%
df = pd.read_csv('Mappe1.csv', sep=';', decimal=',')
df

# %%
df = pd.read_csv('strange.csv', sep=';', decimal=',')
df
# Out:
# 0    4
# Name: "2;", dtype: int64

# %% [markdown]
# # Nach CSV

# %%
df.to_csv('Mappe1Neu.csv', sep=';', decimal=',')

# %% [markdown]
# # SQL

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///:memory:')
df.to_sql('data', engine)
sql_df = pd.read_sql('data', con=engine)
sql_df
# Out:
#    index  1;  "2;"  3
# 0      0   4     4  5

# %%
import sqlalchemy
engine = create_engine('mysql://pcdb:pcdb@192.168.254.158:3306/pcdb')
sql_df = pd.read_sql('select * from pcdb_puppet_factsets', con=engine)
sql_df
# Out:
#    pcdb_puppet_factsets_id  fk_pcdb_puppet_environments_id  \
# 0                        1                               1
# 1                        2                               1
# 2                        3                               2
#
#    fk_pcdb_stammdaten_id  last_pcdb_imports_id factsets_certname  \
# 0                      1                   133         hyper.sgl
# 1                      2                   133        puppet.sgl
# 2                      3                   133        narnia.sgl
#
#                                  factsets_hash  factsets_timestamp  \
# 0  b'febcb562d514b36981c98ac150928bba14bb47bb' 2017-04-20 07:58:05
# 1  b'05909d8626ab50fd7bc9cfdafb311ad990e8ab64' 2017-04-20 07:58:10
# 2  b'd1d15c4e3216eeadca198b3fd569245ae326feda' 2017-04-20 07:56:12
#
#   factsets_producer_timestamp          date_added  date_last_modified
# 0         2017-04-20 07:58:05 2017-04-03 15:23:49 2017-04-20 10:04:30
# 1         2017-04-20 07:58:10 2017-04-03 15:23:50 2017-04-20 10:04:31
# 2         2017-04-20 07:56:12 2017-04-03 15:23:50 2017-04-20 10:04:28

# %% [markdown]
# # JSON

# %%
sql_df.to_json()
# Out:
# '{"pcdb_puppet_factsets_id":{"0":1,"1":2,"2":3},"fk_pcdb_puppet_environments_id":{"0":1,"1":1,"2":2},"fk_pcdb_stammdaten_id":{"0":1,"1":2,"2":3},"last_pcdb_imports_id":{"0":133,"1":133,"2":133},"factsets_certname":{"0":"hyper.sgl","1":"puppet.sgl","2":"narnia.sgl"},"factsets_hash":{"0":"febcb562d514b36981c98ac150928bba14bb47bb","1":"05909d8626ab50fd7bc9cfdafb311ad990e8ab64","2":"d1d15c4e3216eeadca198b3fd569245ae326feda"},"factsets_timestamp":{"0":1492675085000,"1":1492675090000,"2":1492674972000},"factsets_producer_timestamp":{"0":1492675085000,"1":1492675090000,"2":1492674972000},"date_added":{"0":1491233029000,"1":1491233030000,"2":1491233030000},"date_last_modified":{"0":1492682670000,"1":1492682671000,"2":1492682668000}}'

# %% [markdown]
# # Dictionary

# %%
sql_df.to_dict()
# Out:
# {'date_added': {0: Timestamp('2017-04-03 15:23:49'),
#   1: Timestamp('2017-04-03 15:23:50'),
#   2: Timestamp('2017-04-03 15:23:50')},
#  'date_last_modified': {0: Timestamp('2017-04-20 10:04:30'),
#   1: Timestamp('2017-04-20 10:04:31'),
#   2: Timestamp('2017-04-20 10:04:28')},
#  'factsets_certname': {0: 'hyper.sgl', 1: 'puppet.sgl', 2: 'narnia.sgl'},
#  'factsets_hash': {0: b'febcb562d514b36981c98ac150928bba14bb47bb',
#   1: b'05909d8626ab50fd7bc9cfdafb311ad990e8ab64',
#   2: b'd1d15c4e3216eeadca198b3fd569245ae326feda'},
#  'factsets_producer_timestamp': {0: Timestamp('2017-04-20 07:58:05'),
#   1: Timestamp('2017-04-20 07:58:10'),
#   2: Timestamp('2017-04-20 07:56:12')},
#  'factsets_timestamp': {0: Timestamp('2017-04-20 07:58:05'),
#   1: Timestamp('2017-04-20 07:58:10'),
#   2: Timestamp('2017-04-20 07:56:12')},
#  'fk_pcdb_puppet_environments_id': {0: 1, 1: 1, 2: 2},
#  'fk_pcdb_stammdaten_id': {0: 1, 1: 2, 2: 3},
#  'last_pcdb_imports_id': {0: 133, 1: 133, 2: 133},
#  'pcdb_puppet_factsets_id': {0: 1, 1: 2, 2: 3}}
