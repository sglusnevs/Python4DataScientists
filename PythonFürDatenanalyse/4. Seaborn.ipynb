# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tps = sns.load_dataset('tips')

# %%
tps.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Distribution-Diagramme

# %%
import pandas as pd
import numpy as np
sample = pd.DataFrame(np.random.randn(1000), columns=['S'])
sns.distplot(sample['S'], bins=10)

# %%
tps = sns.load_dataset('tips')

# %%
tps.head()

# %%
tps.info()

# %%
sns.distplot(tps['total_bill'], bins=20)

# %%
tps['tip_norm'] = tps['tip'] / (tps['total_bill'] + tps['tip'])
tps.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tip_norm
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.056111
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.138333
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.142799
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.122638
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.128014

# %%
sns.distplot(tps['tip_norm'], bins=20)

# %%
tps.info()

# %%
sns.jointplot(x='total_bill', y='tip_norm', data=tps)

# %%
sns.jointplot(x='total_bill', y='tip_norm', data=tps, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip_norm', data=tps, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip_norm', data=tps, kind='kde')

# %%
sns.jointplot(x='size', y='tip_norm', data=tps, kind='reg')

# %%
sns.rugplot(tps['total_bill'])

# %%
sns.pairplot(data = tps, hue='sex', vars=['total_bill', 'tip'])

# %% [markdown]
# ## Kategoriale-Diagramme

# %% [markdown]
# ### barplot()

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tps)

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tps, estimator=np.min)

# %%
sns.barplot(x = 'sex', y = 'total_bill', hue='day', data = tps, estimator=np.max)

# %% [markdown]
# ### countplot()

# %%
sns.countplot(x = 'sex', data = tps)

# %%
sns.countplot(x = 'day', data = tps, hue='sex')

# %% [markdown]
# ### boxplot()

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tps)

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tps, hue='smoker')

# %% [markdown]
# # Matrix-Digramme

# %%
tips = sns.load_dataset('tips')

# %%
t_corr = tips.corr()

# %%
sns.heatmap(t_corr)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import pandas as pd
pd.pivot_table(tips, values='total_bill', columns='day', index='sex')
# Out:
# day          Thur        Fri        Sat        Sun
# sex
# Male    18.714667  19.857000  20.802542  21.887241
# Female  16.715312  14.145556  19.680357  19.872222

# %%
flights = sns.load_dataset('flights')

# %%
import pandas as pd
pv_flights = pd.pivot_table(flights, columns='month', index='year', values='passengers')
pv_flights.sort_index(ascending=False, inplace=True)

# %%
import pandas as pd
sns.heatmap(pv_flights)

# %%
import pandas as pd
sns.clustermap(pv_flights)
# Out:
# C:\Users\sglusnev\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
